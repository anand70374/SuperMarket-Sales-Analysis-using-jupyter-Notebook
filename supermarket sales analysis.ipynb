# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
import pandas as pd
af = pd.read_csv('supermarket_sales.csv')
af.shape
# Out:
# (1000, 17)

# %%
af.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender
# 0  750-67-8428      A     Yangon        Member  Female  \
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019  \
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
af.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
pd.isnull(af)
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line
# 0         False   False  False          False   False         False  \
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs
# 0         False     False   False  False  False  False    False  False  \
# ...

# %%
pd.isnull(af).sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#initialize the list of lists
data_test = [[ '750-67-8428', ],[ '226-31-3081', 'Electronic accessories'],[ '631-41-3108', 'Home and lifestyle']]
#create pandas dataframe using list
af_test = pd.DataFrame(data_test,columns = ['Invoice ID','Product line'])
af_test
# Out:
#     Invoice ID            Product line
# 0  750-67-8428                    None
# 1  226-31-3081  Electronic accessories
# 2  631-41-3108      Home and lifestyle

# %%
af_test.dropna()
# Out:
#     Invoice ID            Product line
# 1  226-31-3081  Electronic accessories
# 2  631-41-3108      Home and lifestyle

# %%
af_test
# Out:
#     Invoice ID            Product line
# 0  750-67-8428                    None
# 1  226-31-3081  Electronic accessories
# 2  631-41-3108      Home and lifestyle

# %%
#drop null values
af_test.dropna(inplace=True)

# %%
af_test
# Out:
#     Invoice ID            Product line
# 1  226-31-3081  Electronic accessories
# 2  631-41-3108      Home and lifestyle

# %%
#change data type
af['gross income'] = af['gross income'].astype('int')

# %%
af['gross income'].dtypes
# Out:
# dtype('int32')

# %%
af.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
#rename column
af.rename(columns={'gross income': 'income'})
# Out:
#       Invoice ID Branch       City Customer type  Gender
# 0    750-67-8428      A     Yangon        Member  Female  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total
# 0         Health and beauty       74.69         7  26.1415   548.9715  \
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
af.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender
# 0  750-67-8428      A     Yangon        Member  Female  \
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019  \
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
#describe method returns description of the data in the dataframe(i.e. count,mean,std,min,max)
af.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000  \
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     14.861000     6.97270
# std                   0.000000     11.713534     1.71858
# min                   4.761905      0.000000     4.00000
# ...

# %%
#use describe() for specific columns
af[['Tax 5%','Unit price','gross income']].describe()
# Out:
#             Tax 5%   Unit price  gross income
# count  1000.000000  1000.000000   1000.000000
# mean     15.379369    55.672130     14.861000
# std      11.708825    26.494628     11.713534
# min       0.508500    10.080000      0.000000
# 25%       5.924875    32.875000      5.000000
# 50%      12.088000    55.230000     12.000000
# 75%      22.445250    77.935000     22.000000
# max      49.650000    99.960000     49.000000

# %%
af.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
colors =['skyblue','lightcoral']
ax = sns.countplot(x = 'Gender',data = af, palette=colors)

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\My PC\AppData\Local\Temp\ipykernel_23420\855171741.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x = 'Gender',data = af, palette=colors)

# %%
af.groupby(['Gender'], as_index=False)['gross income'].sum().sort_values(by='gross income', ascending=False)
# Out:
#    Gender  gross income
# 0  Female          7738
# 1    Male          7123

# %%
sales_gen= af.groupby(['Gender'], as_index=False)['gross income'].sum().sort_values(by='gross income', ascending=False)

# %%
sns.barplot(x = 'Gender',y= 'gross income',data = sales_gen,hue = 'Gender')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
af.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
ax = sns.countplot(data = af, x = 'Product line', hue='Gender')
sns.set(rc={'figure.figsize':(20,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group by Product line and calculate the sum of gross income
sales_product = af.groupby(['Product line'], as_index=False)['gross income'].sum().sort_values(by='gross income', ascending=False)

# Plot a bar plot
plt.figure(figsize=(12, 6))  # Adjust the figure size as needed
ax = sns.barplot(x='Product line', y='gross income', data=sales_product, hue = 'Product line')

# Iterate over the bars to add labels
for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    ax.annotate(f'{height:.2f}', 
                xy=(bar.get_x() + bar.get_width() / 2, height), 
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

# Add labels and title
ax.set_xlabel('Product Line')
ax.set_ylabel('Total Gross Income')
ax.set_title('Total Gross Income by Product Line')
plt.show()

# %%
sales_City= af.groupby(['City'], as_index=False)['Quantity'].sum().sort_values(by='Quantity', ascending=False).head(10)
plt.figure(figsize=(6, 4))
ax = sns.barplot(x='City', y='Quantity', data=sales_City,hue = 'City')
for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    ax.annotate(f'{height:.2f}', 
                xy=(bar.get_x() + bar.get_width() / 2, height), 
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')
ax.set_xlabel('City')
ax.set_ylabel('Total Quantity')
ax.set_title('Total Quantity by City')
plt.show()

# %%
sales_in= af.groupby(['City','Gender'], as_index=False)['gross income'].sum().sort_values(by='gross income', ascending=False)
plt.figure(figsize=(23, 8))
ax = sns.barplot(x='City', y='gross income', data=sales_in, hue = 'Gender')
for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    ax.annotate(f'{height:.2f}', 
                xy=(bar.get_x() + bar.get_width() / 2, height), 
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

# %%
ax = sns.countplot(data = af, x = 'Branch',hue = 'Branch')
sns.set(rc={'figure.figsize':(4,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_Branch= af.groupby(['Branch'], as_index=False)['gross income'].sum().sort_values(by='gross income', ascending=False)
sns.set(rc={'figure.figsize':(4,5)})
ax = sns.barplot(x='Branch', y='gross income', data=sales_Branch,hue = 'Branch')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
af.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
ax = sns.countplot(data = af, x = 'Payment',hue = 'Payment')
sns.set(rc={'figure.figsize':(4,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_Branch= af.groupby(['Payment'], as_index=False)['gross income'].sum().sort_values(by='gross income', ascending=False)
sns.set(rc={'figure.figsize':(4,5)})
ax = sns.barplot(x='Payment', y='gross income', data=sales_Branch,hue = 'Payment')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_quantity= af.groupby(['Product line'], as_index=False)['Quantity'].sum().sort_values(by='Quantity', ascending=False)
sns.set(rc={'figure.figsize':(15,3)})
ax = sns.barplot(x='Product line', y='Quantity', data=sales_quantity,hue = 'Product line')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
fig1,ax1 = plt.subplots(figsize=(12,7))
af.groupby('Product line')['Quantity'].sum().nlargest(5).sort_values(ascending= False).plot(kind='bar')
for bars in ax.containers:
    ax.bar_label(bars)
